# %% [markdown]
# <a href="https://colab.research.google.com/github/zahBayat/ModelOnCMB/blob/main/Model_b_finall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !pip install git+https://github.com/vafaei-ar/ccgpack.git
# Out:
# ...
#   Cloning https://github.com/vafaei-ar/ccgpack.git to /tmp/pip-req-build-jgne_c3j
#   Running command git clone -q https://github.com/vafaei-ar/ccgpack.git /tmp/pip-req-build-jgne_c3j
# ...
#   Created wheel for ccgpack: filename=ccgpack-0.1.0-cp37-cp37m-linux_x86_64.whl size=910066 sha256=9e22b2df726be215cf06c1b7e530b31dae065bfb30396ce2df710e8241788634
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mphdiji8/wheels/12/6f/95/7ae57565d174cea0e92a0da0a36f289e045f46ef2173da656b
# Successfully built ccgpack
# ...

# %%
import os
import numpy as np
import pylab as plt
from glob import glob
from random import choice,shuffle

# %%
g_files = sorted(glob('/content/drive/MyDrive/data/Healpix_p/*.npy'))

if len(g_files)==0:
    print('Somthing is wrong with initiation.')
    #exit()

print(len(g_files))
# Out:
# 409

# %%
c=0 

for i in range(12):
    c+= np.std(np.load('/content/drive/MyDrive/data/Healpix_p/'+str(i)+'.npy'))
cmb_std = c/12
cmb_std
# Out:
# 0.00010745905213601266

# %%
def get_slice(data,nx,ny):
    """Slice matrix in x and y direction"""
    lx,ly = data.shape  
    if nx==0 or nx==lx:
        slx = slice(0, lx)                
    else:
        idx = np.random.randint(0, lx - nx)            
        slx = slice(idx, (idx+nx))       
    if ny==0 or ny==ly:
        sly = slice(0, ly)                
    else:
        idy = np.random.randint(0, ly - ny)            
        sly = slice(idy, (idy+ny))
    return slx, sly


class OrganizedDataProvider(object):
    def __init__(self,n_files,
                 s2n, cmb_std,
                 nx=0,ny=0,n_buffer=10,
                 reload_rate=100,filt=None ,test=0 , noisy=1):

        self.n_files = n_files
        self.test = test
        self.cmb_std = cmb_std 
        self.s2n = s2n
        self.noisy = noisy

        nmin = len(n_files)
        if n_buffer>= nmin:
            n_buffer = nmin
            self.reload_rate = 0
        else:
            self.reload_rate = reload_rate

        self.nx,self.ny = nx,ny
        self.n_buffer = n_buffer
        if filt is None:
            def filt(x):
                return x
        self.filt = filt
        self.counter = 0
        self.reload()
            
    def reload(self):
        print('Data provider is reloading...')
        self.n_set = []
    #        self.d_set = []
        nind = np.random.randint(0,len(self.n_files))


        for i in range(self.n_buffer):
            filen = self.n_files[nind]
            self.n_set.append(np.load(filen))
           

    def get_data(self): 
        self.counter += 1
        if self.reload_rate:
            if self.counter%self.reload_rate==0: 
                self.reload() 
    #        n = choice(self.n_set)
        ind = choice(np.arange(self.n_buffer))
        n = self.n_set[ind]


        return n

    def pre_process(self, n):
        
        nslice = get_slice(n,self.nx,self.ny)
        n = n[nslice]

        if self.noisy == 1:
            noise = np.random.normal(0, self.cmb_std/self.s2n ,n.shape)
            n = n +noise

        n = self.filt(n)

        return n

    def __call__(self, n, gmus=None): 


        X = []
        # Y = []

        for i in range(n):                
            n = self.get_data()

            sn  = self.pre_process(n)

            sn = (sn - np.mean(sn))/(np.std(sn) + 1e-30)
            sn = np.expand_dims(sn,-1)

            X.append(sn)
            #            Y.append(-np.log10(gmu+1e-30))
            # Y.append(lbl)

        X = np.array(X)
        # Y = np.array(Y)

        return X

# %%
dofilt = 'n'

if dofilt[0]=='y':
    import ccgpack as ccg
    def filt(x):
        return ccg.filters(x,edd_method='sch')
else:
    filt = None

# %%
odp = OrganizedDataProvider(g_files,
                              s2n = 20., 
                              cmb_std = cmb_std,
                              nx=256,ny=256,n_buffer=10,
                              reload_rate=1e5,filt=filt, noisy=1)
# Out:
# Data provider is reloading...

# %%
plt.figure(figsize = (5,5))
plt.imshow(odp(1)[0,:,:,0] , cmap='jet')

# %%
g_test = sorted(glob('/content/drive/MyDrive/data/test/healpix_p/*.npy'))

if len(g_test)==0:
    print('Somthing is wrong with initiation.')
#     exit()
print(len(g_test))
# Out:
# 60

# %%
odp_test = OrganizedDataProvider(g_test,
                                    s2n = 20., 
                                    cmb_std = cmb_std,
                                    nx=256,ny=256,n_buffer=10,
                                     reload_rate=1e5,filt=filt, noisy=1
                                 )
# Out:
# Data provider is reloading...

# %%
y = odp_test(len(g_test))
y.shape
# Out:
# (60, 256, 256, 1)

# %% [markdown]
# # The Model

# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras.models import Model

# %% [markdown]
# - preprocessing the data for out model

# %%
def preprocess(array):
    """
    Normalizes the supplied array and reshapes it into the appropriate format.
    """

    array = array.astype("float32") / 255.0
    array = np.reshape(array, (len(array), 256, 256, 1))
    return array


def display(array1, array2):
    """
    Displays ten random images from each one of the supplied arrays.
    """

    n = 10

    indices = np.random.randint(len(array1), size=n)
    images1 = array1[indices, :]
    images2 = array2[indices, :]

    plt.figure(figsize=(20, 4))
    for i, (image1, image2) in enumerate(zip(images1, images2)):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(image1.reshape(256, 256),cmap='jet')
        # plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(image2.reshape(256, 256),cmap='jet',vmin=0, vmax=0.015)
        # plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.show()

# %%
kernel_size = (5,5)
model1 = tf.keras.models.Sequential([
    
    #encoder
    tf.keras.layers.Conv2D(1, kernel_size , strides=2 , activation='relu', padding='same'),
    # tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    
    # tf.keras.layers.Conv2D(4, kernel_size, strides=2, activation='relu', padding='same'),

    tf.keras.layers.Conv2D(8, kernel_size, strides=2, activation='relu', padding='same'),
    # tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    
    tf.keras.layers.Conv2D(16, kernel_size, strides=2, activation='relu', padding='same'),
    # tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),

    tf.keras.layers.Conv2D(32, kernel_size, strides=2, activation='relu', padding='same'),
    # tf.keras.layers.Flatten()
    # tf.keras.layers.Dense(32)
    # tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    # tf.keras.layers.Conv2D(64, kernel_size, activation='relu', padding='same'),
    # tf.keras.layers.Dropout(rate=0.25) , 

    #decoder
#     tf.keras.layers.Conv2D(64, kernel_size, activation='relu', padding='same'),
# #     tf.keras.layers.Dropout(rate=0.25) , 
#     tf.keras.layers.UpSampling2D((2,2)),
    # np.reshape(code , encode.shape)
    tf.keras.layers.UpSampling2D((2,2)),

    tf.keras.layers.Conv2D(32, kernel_size, activation='relu', padding='same'),
    tf.keras.layers.UpSampling2D((2,2)),
#     tf.keras.layers.Dropout(rate=0.25) ,
    
    tf.keras.layers.Conv2D(16, kernel_size, activation='relu', padding='same'),
    tf.keras.layers.UpSampling2D((2,2)),
    tf.keras.layers.Dropout(rate=0.25) ,
      
    tf.keras.layers.Conv2D(8, kernel_size, activation='relu', padding='same'),
    tf.keras.layers.UpSampling2D((2,2)),

    # tf.keras.layers.Conv2D(4, kernel_size, activation='relu', padding='same'),
    # tf.keras.layers.UpSampling2D((2,2)),
    
    tf.keras.layers.Conv2D(1, kernel_size, activation='sigmoid', padding='same')
    
])

# %%
input=layers.Input(shape = (256, 256,1))
output=model1(input)
              
autoencoder = Model(inputs = input, outputs = output)

# %%
loss = tf.keras.losses.mean_squared_error
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

autoencoder.compile(optimizer=opt, loss=loss)

# %%
autoencoder.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 256, 256, 1)       58139
# ...
# Total params: 58,139
# Trainable params: 58,139
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
iters  = 40

for i in range(epochs):
    for j in range(iters-1):
        x = odp(100)
        autoencoder.fit(x =x , y=x  ,verbose=0 )
    autoencoder.fit(x=x , y=x ,verbose=1, validation_split=0.2)
# Out:
# ...
# 3/3 [==============================] - 0s 136ms/step - loss: 0.5840 - val_loss: 0.5869
# Data provider is reloading...
# ...
# 3/3 [==============================] - 0s 131ms/step - loss: 0.5799 - val_loss: 0.5811

# %%
x_test = y
# test_data = preprocess(x_test)

# %%
autoencoder.evaluate(x, x)
# Out:
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5799
# 0.5798766613006592

# %%
autoencoder.evaluate(x_test, x_test)
# Out:
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5815
# 0.5815351605415344

# %%
train_prediction = autoencoder.predict(x_test)
display(x_test, train_prediction)

# %%
train_prediction[0]

# %%
test_data[0]
